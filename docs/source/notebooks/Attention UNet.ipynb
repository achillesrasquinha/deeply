# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from deeply.model.unet import AttentionUNet

# %%
aunet = AttentionUNet(x = 572, y = 572)

# %%
aunet.plot()
